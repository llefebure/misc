# %% [markdown]
# In [Part 1](https://llefebure.github.io/articles/2019-06/prescribing-behavior-part1), we did some exploratory analysis on the Roam Analytics Medicare Part D data with an eye towards predicting a provider's specialty from their prescribing behavior. To summarize, the key observations for the classification problem were as follows:
#
# * Highly imbalanced classes
# * Widely varying levels of expected separation between classes
# * Drug counts follow a power law distribution, so a TFIDF transformation could be useful
# * Some features are very sparse
# * Strong collinearity in the features
#
# This post (Part 2) focuses on exploring a few models for the multiclass classification task itself.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import sklearn.metrics.base
import warnings
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, f1_score
from sklearn.model_selection import (
    StratifiedKFold, GridSearchCV, train_test_split, cross_val_predict)
pd.options.display.max_columns = None
# %matplotlib inline

# %%
provider_variables = pd.read_csv('data/provider_variables.csv')
vectorizer = np.load('data/vectorizer.npy')[()]
X = np.load('data/X.npy')[()]

# %% [markdown]
# ## Evaluation Strategy
#
# To compare performance across models, we split the data into separate training and test sets and stratify by specialty to ensure that both partitions have a representative class distribution
#
# We will look at the F1 metric to gauge performance. In the multiclass classifcation case, this metric can take different forms. For example, we can compute the F1 score for each class separately and average the resulting values, or we can sum up the true positive, false positive, etc. counts across all classes and compute a global F1 score. The former implicitly weights each class equally despite their unequal sizes, while the latter favors good performance on the larger classes.
#
# Finally, the F1 metric can be undefined for some classes in the case where there are no predicted values for a class, so we ignore the resulting error.

# %%
warnings.filterwarnings(
    'ignore', category=sklearn.exceptions.UndefinedMetricWarning)

# %%
provider_variables_train, provider_variables_test, X_train, X_test = \
    train_test_split(
        provider_variables, X, test_size=.2, stratify=provider_variables.specialty)

# %% [markdown]
# ## Model Building
#
# ### Features
#
# First, we transform the features with TFIDF to upweight the rarer and potentially more distinguishing features while downweighting the most popular features.

# %%
tfidf_transformer = TfidfTransformer()
tfidf_transformer.fit(X_train)
X_train_tfidf = tfidf_transformer.transform(X_train)
X_test_tfidf = tfidf_transformer.transform(X_test)

# %% [markdown]
# ### Logistic Regression
#
# Now that we have features, we build a multinomial logistic regression model. This is a simple model that is easy to train, so it will give us a good baseline level of understanding on the nuances of this problem. The collinearity in the features is problematic if you want to interpret the model coefficients, but it shouldn't affect performance.

# %%
lr_model = GridSearchCV(
    LogisticRegression(
        multi_class='multinomial',
        solver='lbfgs'
    ),
    scoring=['f1_macro', 'f1_micro'],
    param_grid={'C': np.logspace(0, 10, 10)},
    return_train_score=True,
    refit='f1_macro'
)
lr_model.fit(X_train_tfidf, provider_variables_train.specialty)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='multinomial',
#           n_jobs=1, penalty='l2', random_state=None, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'C': array([1.00000e+00, 1.29155e+01, 1.66810e+02, 2.15443e+03, 2.78256e+04,
#        3.59381e+05, 4.64159e+06, 5.99484e+07, 7.74264e+08, 1.00000e+10])},
#        pre_dispatch='2*n_jobs', refit='f1_macro', return_train_score=True,
#        scoring=['f1_macro', 'f1_micro'], verbose=0)

# %%
cv_preds = cross_val_predict(
    lr_model.best_estimator_, X_train_tfidf, provider_variables_train.specialty)

# %% [markdown]
# Looking at the individual per class F1 scores, we see a pretty wide range of values. While the larger classes tend to have higher scores, the relationship is not perfect. We also see that the observations from Part 1 that some of the well separated classes such as Neurology and Rheumatology should be fairly easy to predict are indeed true as these classes have an F1 of over .95.
#
# In looking at the confusion matrix of the cross validated predictions, we can definitely see patterns in the errors for the low performing classes. The biggest issue appears to be distinguishing between very similar classes rather than failing completely on strictly small sample classes. For example:
#
# * Child & Adolescent Psychiatry getting mistaken for Psychiatry.
# * Acute Care getting mistaken for Family.
# * Primary Care getting mistaken for Family.
# * Interventional Cardiology getting mistaken for Cardiovascular Disease.

# %%
class_labels = provider_variables_train.specialty.value_counts()
f1_scores = f1_score(
    provider_variables_train.specialty, cv_preds, labels=class_labels.index,
    average=None)
class_summary = pd.DataFrame(
    list(zip(class_labels.index, f1_scores, class_labels.values,
             np.argsort(-f1_scores).argsort() + 1)),
    columns=['Specialty', 'F1', 'True Count', 'F1 Rank']
)
class_summary
# Out:
#                                Specialty        F1  True Count  F1 Rank
# 0                 Cardiovascular Disease  0.898652        4249        6
# 1                                 Family  0.643547        3999       12
# 2                             Psychiatry  0.914622        2433        5
# 3                                Medical  0.240791        1650       17
# 4                     Geriatric Medicine  0.654655        1544       11
# 5                             Nephrology  0.931343        1516        4
# 6                              Neurology  0.951421        1393        2
# 7   Endocrinology, Diabetes & Metabolism  0.934723        1116        3
# 8                           Adult Health  0.137077         756       20
# 9                           Rheumatology  0.953229         683        1
# 10                     Pulmonary Disease  0.817259         599        9
# 11                    Infectious Disease  0.721133         451       10
# 12                        Adult Medicine  0.101040         401       22
# 13                 Hematology & Oncology  0.850704         353        7
# 14                      Gastroenterology  0.817568         313        8
# 15             Interventional Cardiology  0.068241         312       23
# 16                   Psych/Mental Health  0.265985         262       16
# 17                           Gerontology  0.158491         158       19
# 18                          Primary Care  0.010753         153       26
# 19                         Pain Medicine  0.596774         118       13
# 20                   Adolescent Medicine  0.000000         118       27
# 21                            Acute Care  0.017857          97       25
# 22                       Sports Medicine  0.047244          86       24
# 23          Interventional Pain Medicine  0.458333          48       15
# 24         Child & Adolescent Psychiatry  0.000000          43       28
# 25                    Addiction Medicine  0.109091          43       21
# 26                Critical Care Medicine  0.000000          42       29
# 27                      Medical Oncology  0.181818          42       18
# 28    Clinical Cardiac Electrophysiology  0.555556          40       14

# %%
confusion_matrix_cv_preds = pd.DataFrame(
    confusion_matrix(provider_variables_train.specialty, cv_preds,
                     labels=class_labels.index))
confusion_matrix_cv_preds.index = class_labels.index
confusion_matrix_cv_preds.columns = class_labels.index
confusion_matrix_cv_preds # element (i,j) refers to number in class i predicted to be in class j
# Out:
#                                       Cardiovascular Disease  Family  \
# Cardiovascular Disease                                  3999      40
# Family                                                    59    2867
# Psychiatry                                                 0      11
# Medical                                                   38     942
# Geriatric Medicine                                        45     144
# Nephrology                                                18      22
# Neurology                                                  1      14
# Endocrinology, Diabetes & Metabolism                       6      22
# Adult Health                                              46     364
# Rheumatology                                               2       7
# Pulmonary Disease                                         14      26
# Infectious Disease                                         6      26
# Adult Medicine                                            34     115
# Hematology & Oncology                                      7       6
# Gastroenterology                                          12      16
# Interventional Cardiology                                295       1
# Psych/Mental Health                                        0       1
# Gerontology                                                0      51
# Primary Care                                               7      91
# Pain Medicine                                              0       8
# Adolescent Medicine                                        9      30
# Acute Care                                                19      50
# Sports Medicine                                            3      40
# Interventional Pain Medicine                               0       3
# Child & Adolescent Psychiatry                              0       0
# Addiction Medicine                                         2       8
# Critical Care Medicine                                    10       5
# Medical Oncology                                           0       0
# Clinical Cardiac Electrophysiology                        19       1
#
#                                       Psychiatry  Medical  Geriatric Medicine  \
# Cardiovascular Disease                         1       26                  50
# Family                                        26      531                 123
# Psychiatry                                  2330        7                   2
# Medical                                       11      353                  65
# Geriatric Medicine                             2       47                1090
# Nephrology                                     0       11                  25
# Neurology                                     22       17                   3
# Endocrinology, Diabetes & Metabolism           1       15                  23
# Adult Health                                   8       85                  60
# Rheumatology                                   0       12                  12
# Pulmonary Disease                              0       12                  39
# Infectious Disease                             0       12                  29
# Adult Medicine                                 0       66                 105
# Hematology & Oncology                          0        3                  12
# Gastroenterology                               1        7                  17
# Interventional Cardiology                      0        1                   0
# Psych/Mental Health                          206        0                   0
# Gerontology                                    0        8                  47
# Primary Care                                   3       22                  11
# Pain Medicine                                  0        7                   3
# Adolescent Medicine                            3       12                  37
# Acute Care                                     1        5                   5
# Sports Medicine                                0       18                  10
# Interventional Pain Medicine                   0        0                   0
# Child & Adolescent Psychiatry                 42        0                   0
# Addiction Medicine                             5        3                   9
# Critical Care Medicine                         0        2                   6
# Medical Oncology                               0        0                   3
# Clinical Cardiac Electrophysiology             0        0                   0
#
#                                       Nephrology  Neurology  \
# Cardiovascular Disease                         9          1
# Family                                        27         12
# Psychiatry                                     1          7
# Medical                                        9         23
# Geriatric Medicine                            13          1
# Nephrology                                  1404          0
# Neurology                                      0       1322
# Endocrinology, Diabetes & Metabolism           2          0
# Adult Health                                  14          4
# Rheumatology                                   0          0
# Pulmonary Disease                              4          0
# Infectious Disease                             2          0
# Adult Medicine                                 3          0
# Hematology & Oncology                          1          0
# Gastroenterology                               1          1
# Interventional Cardiology                      0          0
# Psych/Mental Health                            0          0
# Gerontology                                    2          1
# Primary Care                                   1          1
# Pain Medicine                                  0          8
# Adolescent Medicine                            3          0
# Acute Care                                     1          2
# Sports Medicine                                0          0
# Interventional Pain Medicine                   0          2
# Child & Adolescent Psychiatry                  0          0
# Addiction Medicine                             0          1
# Critical Care Medicine                         2          0
# Medical Oncology                               0          0
# Clinical Cardiac Electrophysiology             0          0
#
#                                       Endocrinology, Diabetes & Metabolism  \
# Cardiovascular Disease                                                   2
# Family                                                                  19
# Psychiatry                                                               0
# Medical                                                                 15
# Geriatric Medicine                                                       3
# Nephrology                                                               2
# Neurology                                                                0
# Endocrinology, Diabetes & Metabolism                                  1031
# Adult Health                                                            13
# Rheumatology                                                             0
# Pulmonary Disease                                                        0
# Infectious Disease                                                       0
# Adult Medicine                                                           2
# Hematology & Oncology                                                    1
# Gastroenterology                                                         1
# Interventional Cardiology                                                0
# Psych/Mental Health                                                      0
# Gerontology                                                              0
# Primary Care                                                             0
# Pain Medicine                                                            0
# Adolescent Medicine                                                      0
# Acute Care                                                               1
# Sports Medicine                                                          0
# Interventional Pain Medicine                                             0
# Child & Adolescent Psychiatry                                            0
# Addiction Medicine                                                       0
# Critical Care Medicine                                                   0
# Medical Oncology                                                         0
# Clinical Cardiac Electrophysiology                                       0
#
#                                       Adult Health  Rheumatology  \
# Cardiovascular Disease                          14             1
# Family                                         139             6
# Psychiatry                                       3             0
# Medical                                         62             8
# Geriatric Medicine                              43             0
# Nephrology                                       8             1
# Neurology                                        0             0
# Endocrinology, Diabetes & Metabolism             6             0
# Adult Health                                    83             1
# Rheumatology                                     3           642
# Pulmonary Disease                                6             1
# Infectious Disease                              15             0
# Adult Medicine                                  17             0
# Hematology & Oncology                            4             1
# Gastroenterology                                 6             0
# Interventional Cardiology                        1             0
# Psych/Mental Health                              1             0
# Gerontology                                     24             0
# Primary Care                                     5             0
# Pain Medicine                                    1             0
# Adolescent Medicine                              6             2
# Acute Care                                       4             1
# Sports Medicine                                  3             0
# Interventional Pain Medicine                     0             0
# Child & Adolescent Psychiatry                    0             0
# Addiction Medicine                               0             0
# Critical Care Medicine                           1             0
# Medical Oncology                                 0             0
# Clinical Cardiac Electrophysiology               0             0
#
#                                       Pulmonary Disease  Infectious Disease  \
# Cardiovascular Disease                                7                   3
# Family                                               18                  38
# Psychiatry                                            0                   0
# Medical                                              10                  30
# Geriatric Medicine                                   25                  13
# Nephrology                                            9                   4
# Neurology                                             0                   0
# Endocrinology, Diabetes & Metabolism                  0                   0
# Adult Health                                          7                  22
# Rheumatology                                          2                   2
# Pulmonary Disease                                   483                   4
# Infectious Disease                                    3                 331
# Adult Medicine                                        2                   6
# Hematology & Oncology                                 2                   4
# Gastroenterology                                      0                   4
# Interventional Cardiology                             0                   0
# Psych/Mental Health                                   0                   0
# Gerontology                                           1                   0
# Primary Care                                          2                   3
# Pain Medicine                                         0                   0
# Adolescent Medicine                                   2                   0
# Acute Care                                            1                   0
# Sports Medicine                                       0                   2
# Interventional Pain Medicine                          0                   0
# Child & Adolescent Psychiatry                         0                   0
# Addiction Medicine                                    0                   0
# Critical Care Medicine                                9                   1
# Medical Oncology                                      0                   0
# Clinical Cardiac Electrophysiology                    0                   0
#
#                                       Adult Medicine  Hematology & Oncology  \
# Cardiovascular Disease                            20                      3
# Family                                            47                      2
# Psychiatry                                         0                      0
# Medical                                           35                      0
# Geriatric Medicine                                55                      5
# Nephrology                                         5                      3
# Neurology                                          0                      0
# Endocrinology, Diabetes & Metabolism               6                      0
# Adult Health                                      12                      1
# Rheumatology                                       0                      0
# Pulmonary Disease                                  5                      0
# Infectious Disease                                12                      1
# Adult Medicine                                    34                      0
# Hematology & Oncology                              0                    302
# Gastroenterology                                   2                      2
# Interventional Cardiology                          0                      0
# Psych/Mental Health                                0                      0
# Gerontology                                        1                      0
# Primary Care                                       3                      2
# Pain Medicine                                      1                      0
# Adolescent Medicine                               11                      0
# Acute Care                                         3                      0
# Sports Medicine                                    6                      0
# Interventional Pain Medicine                       0                      0
# Child & Adolescent Psychiatry                      0                      0
# Addiction Medicine                                11                      1
# Critical Care Medicine                             3                      1
# Medical Oncology                                   0                     34
# Clinical Cardiac Electrophysiology                 0                      0
#
#                                       Gastroenterology  \
# Cardiovascular Disease                               4
# Family                                               5
# Psychiatry                                           0
# Medical                                              4
# Geriatric Medicine                                   6
# Nephrology                                           1
# Neurology                                            0
# Endocrinology, Diabetes & Metabolism                 0
# Adult Health                                         3
# Rheumatology                                         0
# Pulmonary Disease                                    2
# Infectious Disease                                   6
# Adult Medicine                                       4
# Hematology & Oncology                                0
# Gastroenterology                                   242
# Interventional Cardiology                            0
# Psych/Mental Health                                  0
# Gerontology                                          0
# Primary Care                                         1
# Pain Medicine                                        0
# Adolescent Medicine                                  1
# Acute Care                                           0
# Sports Medicine                                      0
# Interventional Pain Medicine                         0
# Child & Adolescent Psychiatry                        0
# Addiction Medicine                                   0
# Critical Care Medicine                               0
# Medical Oncology                                     0
# Clinical Cardiac Electrophysiology                   0
#
#                                       Interventional Cardiology  \
# Cardiovascular Disease                                       52
# Family                                                        2
# Psychiatry                                                    0
# Medical                                                       1
# Geriatric Medicine                                            1
# Nephrology                                                    0
# Neurology                                                     0
# Endocrinology, Diabetes & Metabolism                          0
# Adult Health                                                  0
# Rheumatology                                                  0
# Pulmonary Disease                                             0
# Infectious Disease                                            0
# Adult Medicine                                                0
# Hematology & Oncology                                         0
# Gastroenterology                                              0
# Interventional Cardiology                                    13
# Psych/Mental Health                                           0
# Gerontology                                                   0
# Primary Care                                                  0
# Pain Medicine                                                 0
# Adolescent Medicine                                           0
# Acute Care                                                    0
# Sports Medicine                                               0
# Interventional Pain Medicine                                  0
# Child & Adolescent Psychiatry                                 0
# Addiction Medicine                                            0
# Critical Care Medicine                                        0
# Medical Oncology                                              0
# Clinical Cardiac Electrophysiology                            0
#
#                                       Psych/Mental Health  Gerontology  \
# Cardiovascular Disease                                  0            1
# Family                                                  8           23
# Psychiatry                                             68            0
# Medical                                                 0            7
# Geriatric Medicine                                      0           33
# Nephrology                                              0            0
# Neurology                                               0            0
# Endocrinology, Diabetes & Metabolism                    0            0
# Adult Health                                            0           20
# Rheumatology                                            0            0
# Pulmonary Disease                                       0            0
# Infectious Disease                                      0            1
# Adult Medicine                                          0            0
# Hematology & Oncology                                   0            0
# Gastroenterology                                        0            0
# Interventional Cardiology                               0            0
# Psych/Mental Health                                    52            1
# Gerontology                                             0           21
# Primary Care                                            0            0
# Pain Medicine                                           0            0
# Adolescent Medicine                                     0            0
# Acute Care                                              0            0
# Sports Medicine                                         0            0
# Interventional Pain Medicine                            0            0
# Child & Adolescent Psychiatry                           1            0
# Addiction Medicine                                      0            0
# Critical Care Medicine                                  0            0
# Medical Oncology                                        0            0
# Clinical Cardiac Electrophysiology                      0            0
#
#                                       Primary Care  Pain Medicine  \
# Cardiovascular Disease                           0              0
# Family                                          10              7
# Psychiatry                                       0              3
# Medical                                          8             10
# Geriatric Medicine                               1              0
# Nephrology                                       1              0
# Neurology                                        0              8
# Endocrinology, Diabetes & Metabolism             0              0
# Adult Health                                     4              2
# Rheumatology                                     0              1
# Pulmonary Disease                                1              0
# Infectious Disease                               2              0
# Adult Medicine                                   1              0
# Hematology & Oncology                            0              1
# Gastroenterology                                 0              0
# Interventional Cardiology                        0              0
# Psych/Mental Health                              0              0
# Gerontology                                      0              1
# Primary Care                                     1              0
# Pain Medicine                                    0             74
# Adolescent Medicine                              2              0
# Acute Care                                       0              2
# Sports Medicine                                  0              0
# Interventional Pain Medicine                     0             21
# Child & Adolescent Psychiatry                    0              0
# Addiction Medicine                               0              0
# Critical Care Medicine                           2              0
# Medical Oncology                                 0              0
# Clinical Cardiac Electrophysiology               0              0
#
#                                       Adolescent Medicine  Acute Care  \
# Cardiovascular Disease                                  3           3
# Family                                                  8           7
# Psychiatry                                              0           0
# Medical                                                 8           3
# Geriatric Medicine                                     11           0
# Nephrology                                              1           0
# Neurology                                               0           0
# Endocrinology, Diabetes & Metabolism                    2           0
# Adult Health                                            1           1
# Rheumatology                                            0           0
# Pulmonary Disease                                       2           0
# Infectious Disease                                      2           0
# Adult Medicine                                          1           0
# Hematology & Oncology                                   0           0
# Gastroenterology                                        0           0
# Interventional Cardiology                               0           0
# Psych/Mental Health                                     0           0
# Gerontology                                             1           0
# Primary Care                                            0           0
# Pain Medicine                                           0           0
# Adolescent Medicine                                     0           0
# Acute Care                                              0           1
# Sports Medicine                                         1           0
# Interventional Pain Medicine                            0           0
# Child & Adolescent Psychiatry                           0           0
# Addiction Medicine                                      0           0
# Critical Care Medicine                                  0           0
# Medical Oncology                                        0           0
# Clinical Cardiac Electrophysiology                      0           0
#
#                                       Sports Medicine  \
# Cardiovascular Disease                              0
# Family                                              9
# Psychiatry                                          0
# Medical                                             6
# Geriatric Medicine                                  3
# Nephrology                                          0
# Neurology                                           1
# Endocrinology, Diabetes & Metabolism                2
# Adult Health                                        4
# Rheumatology                                        0
# Pulmonary Disease                                   0
# Infectious Disease                                  3
# Adult Medicine                                      8
# Hematology & Oncology                               0
# Gastroenterology                                    1
# Interventional Cardiology                           0
# Psych/Mental Health                                 0
# Gerontology                                         0
# Primary Care                                        0
# Pain Medicine                                       0
# Adolescent Medicine                                 0
# Acute Care                                          1
# Sports Medicine                                     3
# Interventional Pain Medicine                        0
# Child & Adolescent Psychiatry                       0
# Addiction Medicine                                  0
# Critical Care Medicine                              0
# Medical Oncology                                    0
# Clinical Cardiac Electrophysiology                  0
#
#                                       Interventional Pain Medicine  \
# Cardiovascular Disease                                           0
# Family                                                           4
# Psychiatry                                                       0
# Medical                                                          2
# Geriatric Medicine                                               0
# Nephrology                                                       0
# Neurology                                                        3
# Endocrinology, Diabetes & Metabolism                             0
# Adult Health                                                     1
# Rheumatology                                                     0
# Pulmonary Disease                                                0
# Infectious Disease                                               0
# Adult Medicine                                                   0
# Hematology & Oncology                                            0
# Gastroenterology                                                 0
# Interventional Cardiology                                        0
# Psych/Mental Health                                              0
# Gerontology                                                      0
# Primary Care                                                     0
# Pain Medicine                                                   16
# Adolescent Medicine                                              0
# Acute Care                                                       0
# Sports Medicine                                                  0
# Interventional Pain Medicine                                    22
# Child & Adolescent Psychiatry                                    0
# Addiction Medicine                                               0
# Critical Care Medicine                                           0
# Medical Oncology                                                 0
# Clinical Cardiac Electrophysiology                               0
#
#                                       Child & Adolescent Psychiatry  \
# Cardiovascular Disease                                            0
# Family                                                            0
# Psychiatry                                                        1
# Medical                                                           0
# Geriatric Medicine                                                0
# Nephrology                                                        0
# Neurology                                                         0
# Endocrinology, Diabetes & Metabolism                              0
# Adult Health                                                      0
# Rheumatology                                                      0
# Pulmonary Disease                                                 0
# Infectious Disease                                                0
# Adult Medicine                                                    0
# Hematology & Oncology                                             0
# Gastroenterology                                                  0
# Interventional Cardiology                                         0
# Psych/Mental Health                                               1
# Gerontology                                                       0
# Primary Care                                                      0
# Pain Medicine                                                     0
# Adolescent Medicine                                               0
# Acute Care                                                        0
# Sports Medicine                                                   0
# Interventional Pain Medicine                                      0
# Child & Adolescent Psychiatry                                     0
# Addiction Medicine                                                0
# Critical Care Medicine                                            0
# Medical Oncology                                                  0
# Clinical Cardiac Electrophysiology                                0
#
#                                       Addiction Medicine  \
# Cardiovascular Disease                                 0
# Family                                                 1
# Psychiatry                                             0
# Medical                                                0
# Geriatric Medicine                                     2
# Nephrology                                             1
# Neurology                                              2
# Endocrinology, Diabetes & Metabolism                   0
# Adult Health                                           0
# Rheumatology                                           0
# Pulmonary Disease                                      0
# Infectious Disease                                     0
# Adult Medicine                                         2
# Hematology & Oncology                                  1
# Gastroenterology                                       0
# Interventional Cardiology                              0
# Psych/Mental Health                                    0
# Gerontology                                            0
# Primary Care                                           0
# Pain Medicine                                          0
# Adolescent Medicine                                    0
# Acute Care                                             0
# Sports Medicine                                        0
# Interventional Pain Medicine                           0
# Child & Adolescent Psychiatry                          0
# Addiction Medicine                                     3
# Critical Care Medicine                                 0
# Medical Oncology                                       0
# Clinical Cardiac Electrophysiology                     0
#
#                                       Critical Care Medicine  \
# Cardiovascular Disease                                     0
# Family                                                     0
# Psychiatry                                                 0
# Medical                                                    0
# Geriatric Medicine                                         1
# Nephrology                                                 0
# Neurology                                                  0
# Endocrinology, Diabetes & Metabolism                       0
# Adult Health                                               0
# Rheumatology                                               0
# Pulmonary Disease                                          0
# Infectious Disease                                         0
# Adult Medicine                                             1
# Hematology & Oncology                                      0
# Gastroenterology                                           0
# Interventional Cardiology                                  0
# Psych/Mental Health                                        0
# Gerontology                                                0
# Primary Care                                               0
# Pain Medicine                                              0
# Adolescent Medicine                                        0
# Acute Care                                                 0
# Sports Medicine                                            0
# Interventional Pain Medicine                               0
# Child & Adolescent Psychiatry                              0
# Addiction Medicine                                         0
# Critical Care Medicine                                     0
# Medical Oncology                                           0
# Clinical Cardiac Electrophysiology                         0
#
#                                       Medical Oncology  \
# Cardiovascular Disease                               0
# Family                                               0
# Psychiatry                                           0
# Medical                                              0
# Geriatric Medicine                                   0
# Nephrology                                           0
# Neurology                                            0
# Endocrinology, Diabetes & Metabolism                 0
# Adult Health                                         0
# Rheumatology                                         0
# Pulmonary Disease                                    0
# Infectious Disease                                   0
# Adult Medicine                                       0
# Hematology & Oncology                                8
# Gastroenterology                                     0
# Interventional Cardiology                            0
# Psych/Mental Health                                  0
# Gerontology                                          0
# Primary Care                                         0
# Pain Medicine                                        0
# Adolescent Medicine                                  0
# Acute Care                                           0
# Sports Medicine                                      0
# Interventional Pain Medicine                         0
# Child & Adolescent Psychiatry                        0
# Addiction Medicine                                   0
# Critical Care Medicine                               0
# Medical Oncology                                     5
# Clinical Cardiac Electrophysiology                   0
#
#                                       Clinical Cardiac Electrophysiology
# Cardiovascular Disease                                                10
# Family                                                                 1
# Psychiatry                                                             0
# Medical                                                                0
# Geriatric Medicine                                                     0
# Nephrology                                                             0
# Neurology                                                              0
# Endocrinology, Diabetes & Metabolism                                   0
# Adult Health                                                           0
# Rheumatology                                                           0
# Pulmonary Disease                                                      0
# Infectious Disease                                                     0
# Adult Medicine                                                         0
# Hematology & Oncology                                                  0
# Gastroenterology                                                       0
# Interventional Cardiology                                              1
# Psych/Mental Health                                                    0
# Gerontology                                                            0
# Primary Care                                                           0
# Pain Medicine                                                          0
# Adolescent Medicine                                                    0
# Acute Care                                                             0
# Sports Medicine                                                        0
# Interventional Pain Medicine                                           0
# Child & Adolescent Psychiatry                                          0
# Addiction Medicine                                                     0
# Critical Care Medicine                                                 0
# Medical Oncology                                                       0
# Clinical Cardiac Electrophysiology                                    20

# %% [markdown]
# Finally, we will obtain the F1 scores on the test data.

# %%
print('Macro F1: ', f1_score(
    provider_variables_test.specialty, lr_model.predict(X_test_tfidf),
    average='macro'))
print('Micro F1: ', f1_score(
    provider_variables_test.specialty, lr_model.predict(X_test_tfidf),
    average='micro'))
# Out:
# Macro F1:  0.4571918561271133
# Micro F1:  0.7372719374456995

# %% [markdown]
# ### XGBoost
#
# For the sake of having something to compare the logistic regression model against, we train a vanilla XGBoost model with the default parameters. Performance is pretty comparable to that of the Logistic Regression. It underperforms on the Macro F1 and outperforms on the Micro F1, showing that the model is biased towards better performance on the larger classes while ignoring smaller ones.

# %%
xgb_model = XGBClassifier()
xgb_model.fit(X_train_tfidf, provider_variables_train.specialty)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bynode=1, colsample_bytree=1, gamma=0, learning_rate=0.1,
#        max_delta_step=0, max_depth=3, min_child_weight=1, missing=None,
#        n_estimators=100, n_jobs=1, nthread=None,
#        objective='multi:softprob', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=None,
#        subsample=1, verbosity=1)

# %%
preds = model.predict(X_test_tfidf)
# Out:
# /Users/lukelefebure/envs/python_3.6.3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %%
print('Macro F1: ', f1_score(
    provider_variables_test.specialty, xgb_model.predict(X_test_tfidf),
    average='macro'))
print('Micro F1: ', f1_score(
    provider_variables_test.specialty, xgb_model.predict(X_test_tfidf),
    average='micro'))
# Out:
# /Users/lukelefebure/envs/python_3.6.3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:
# Macro F1:  0.4193069563936367
# Micro F1:  0.7449174630755866
# /Users/lukelefebure/envs/python_3.6.3/lib/python3.6/site-packages/sklearn/preprocessing/label.py:151: DeprecationWarning: The truth value of an empty array is ambiguous. Returning False, but in future this will result in an error. Use `array.size > 0` to check that an array is not empty.
#   if diff:

# %% [markdown]
# ## Conclusion
#
# The most interesting finding here for me was that the class imbalance really didn't seem to be the biggest problem, rather the similarity between certain classes was. The model had very good accuracy on small sample specialized domains such as Hematology & Oncology but struggled with the ones that had highly related classes such as Child & Adolescent Psychiatry.
#
# I didn't really do any model tuning here, though if this were a problem worth pursuing further, I think my next steps would be to look more closely at the lower performing classes. For example, if we tried to build a binary classifier for Child & Adolescent Psychiatry vs. Pyschiatry, would there be any distinguishing features between the two?
