# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer

# %%
df = pd.read_csv("../data/processed.csv")
plens = df.text.str.len()
plens.hist()
# Out:
# <Axes: >

# %%
st = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")

# %%
tok_lens = pd.Series(map(len, st.tokenizer([v for v in df.text.values if isinstance(v, str)])["input_ids"]))

# %%
tok_lens.hist()
# Out:
# <Axes: >
